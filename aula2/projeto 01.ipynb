# %%
"""
1-MENU
se a opção for 1
Informar nome se nome existir falar que existe mesma coisa para o numero

se a opção for 2
mostrar contatos existentes

se a opção for 3
procurar contato

se a opção for 4
atulizar contato

se a opção for 5
excluir contato

se a opção for 6
sair do programa

se opção for nenhuma acima 
peça para escolhar alguma acima

"""

# %%
contato = {}

def add_contato(nome, numero, contato):
         contato[nome] = contato
         contato[numero] = contato
         pass

def visu_contato():
        if not contato:
              print('Nenhum contato encontrado')
        else:
              for nome, numero in contato.items():
                    print(f'{nome},{numero}')


def menu():
        print('\nMenu')
        print('1.Adicionar Contato')
        print('2.Visualizar Contatos')
        print('3.Buscar Contato')
        print('4.Atualizar Contato')
        print('5.Excluir Contato')
        print('6.Sair')
        #print('1.Escolha uma opção(1-6):')
        while True:

                escolha = input('escolha uma opção')

#1 ADICIONAR CONTATO
                if escolha == '1':
                    print(escolha)
                    nome = input('Informe o nome do contato')
                    numero = input('Informe o numero')
                    add_contato(nome, numero)


#2 VISUALIZAR CONTATOS
                elif escolha == '2':
                    print(escolha)
                    visu_contato()
#3 BUSCAR CONTATOS
                elif escolha == '3':
                    print(escolha)

#4 ATUALIZAR CONTATO
                elif escolha == '4':
                    nome = input('Me informe o nome a ser atualizado: ')
                    if nome in contatos:
                        
                    print(escolha)

#5 EXCLUIR CONTATO
                elif escolha == '5':
                    print(escolha)

#6 SAIR DO PROGRAMA
                elif escolha == '6':
                    print('Saindo do programa')
                    break
                else:
                    print(escolha,'Opção invalida. Escolha uma das opções')

menu()
# Out:
# Menu
# 1.Adicionar Contato
# 2.Visualizar Contatos
# 3.Buscar Contato
# 4.Atualizar Contato
# 5.Excluir Contato
# 6.Sair
# 2
# Nenhum contato encontrado
# 2
# Nenhum contato encontrado
# 2
# Nenhum contato encontrado
# 2
# Nenhum contato encontrado
# 2
# Nenhum contato encontrado
# 2
# Nenhum contato encontrado
# 2
# Nenhum contato encontrado
